# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el archivo CSV (reemplazá 'tu_archivo.csv' por el nombre exacto de tu archivo)
df = pd.read_csv('PopularidadLenguajes.csv')

print("¡Dataset cargado correctamente!")
# Out:
# ¡Dataset cargado correctamente!

# %%
# 1. Ver las primeras 5 filas de la tabla
df.head()
# Out:
#    Language  Year_Introduced  StackOverflow_Popularity  Job_Demand_Index  \
# 0     Julia             2012                        93                98
# 1   Fortran             1957                        96                76
# 2       Zig             2016                       100                94
# 3      Ruby             1995                        86                92
# 4  Assembly             1949                        62                97
#
#    Developer_Usage_Score  Popularity_Rating  Rank  \
# 0                     99               9.67   1.0
# 1                     97               8.97   2.5
# 2                     75               8.97   2.5
# 3                     77               8.50   4.0
# 4                     83               8.07   5.0
#
#                                           Created_By  \
# 0  Jeff Bezanson, Stefan Karpinski, Viral B. Shah...
# 1                                  John Backus (IBM)
# 2                                      Andrew Kelley
# ...

# %%
# 2. Ver el nombre de las columnas, tipos de datos y valores nulos
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Language                  35 non-null     str
#  1   Year_Introduced           35 non-null     int64
#  2   StackOverflow_Popularity  35 non-null     int64
#  3   Job_Demand_Index          35 non-null     int64
#  4   Developer_Usage_Score     35 non-null     int64
#  5   Popularity_Rating         35 non-null     float64
#  6   Rank                      35 non-null     float64
#  7   Created_By                35 non-null     str
#  8   Creator                   35 non-null     str
# dtypes: float64(2), int64(4), str(3)
# memory usage: 2.6 KB

# %%
# 3. Ver estadísticas descriptivas (promedios, mínimos, máximos) de las columnas numéricas
df.describe()
# Out:
#        Year_Introduced  StackOverflow_Popularity  Job_Demand_Index  \
# count        35.000000                 35.000000         35.000000
# mean       1995.457143                 71.514286         66.885714
# std          17.026524                 16.962539         20.197221
# min        1949.000000                 40.000000         35.000000
# 25%        1988.000000                 60.000000         52.500000
# 50%        1995.000000                 72.000000         66.000000
# 75%        2010.500000                 85.500000         84.500000
# max        2016.000000                100.000000        100.000000
#
#        Developer_Usage_Score  Popularity_Rating       Rank
# count              35.000000          35.000000  35.000000
# mean               66.142857           6.818286  18.000000
# std                20.858265           1.223499  10.244798
# min                30.000000           4.600000   1.000000
# 25%                49.500000           6.120000   9.500000
# ...

# %%
top_10 = df.sort_values(by='Rank', ascending=True).head(10)
top_10[['Language', 'Year_Introduced', 'Job_Demand_Index', 'Rank']]
# Out:
#      Language  Year_Introduced  Job_Demand_Index  Rank
# 0       Julia             2012                98   1.0
# 1     Fortran             1957                76   2.5
# 2         Zig             2016                94   2.5
# 3        Ruby             1995                92   4.0
# 4    Assembly             1949                97   5.0
# 5      Elixir             2011                69   6.0
# 6          C#             2000               100   7.0
# 7      Groovy             2003                61   8.0
# 8  JavaScript             1995                94   9.0
# 9        Bash             1989                73  10.0

# %%
plt.figure(figsize=(10, 5))

# Gráfico de barras: Eje X = Lenguaje, Eje Y = Demanda Laboral
plt.bar(top_10['Language'], top_10['Job_Demand_Index'], color='skyblue')

plt.title('Demanda Laboral de los 10 Lenguajes Mejor Rankeados')
plt.xlabel('Lenguaje de Programación')
plt.ylabel('Índice de Demanda Laboral (0 - 100)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['Language'].unique()
# Out:
# <StringArray>
# [       'Julia',      'Fortran',          'Zig',         'Ruby',
#      'Assembly',       'Elixir',           'C#',       'Groovy',
#    'JavaScript',         'Bash',   'TypeScript',     'Solidity',
#           'Nim',        'Scala',            'R',       'Python',
#             'C',       'MATLAB',          'PHP',         'Dart',
#   'Objective-C',        'COBOL',           'Go',         'Java',
#           'C++',       'Delphi',        'Swift',      'Haskell',
#        'Kotlin',   'PowerShell',          'Ada',         'Rust',
#          'Perl', 'Visual Basic',      'Crystal']
# Length: 35, dtype: str

# %%
creadores = {
    'Julia': 'Jeff Bezanson, Stefan Karpinski, Viral B. Shah, Alan Edelman',
    'Fortran': 'John Backus (IBM)',
    'Zig': 'Andrew Kelley',
    'Ruby': 'Yukihiro Matsumoto',
    'Assembly': 'Kathleen Booth',
    'Elixir': 'José Valim',
    'C#': 'Anders Hejlsberg (Microsoft)',
    'Groovy': 'James Strachan',
    'JavaScript': 'Brendan Eich',
    'Bash': 'Brian Fox',
    'TypeScript': 'Anders Hejlsberg (Microsoft)',
    'Solidity': 'Gavin Wood',
    'Nim': 'Andreas Rumpf',
    'Scala': 'Martin Odersky',
    'R': 'Ross Ihaka y Robert Gentleman',
    'Python': 'Guido van Rossum',
    'C': 'Dennis Ritchie',
    'MATLAB': 'Cleve Moler',
    'PHP': 'Rasmus Lerdorf',
    'Dart': 'Lars Bak y Kasper Lund (Google)',
    'Objective-C': 'Brad Cox y Tom Love',
    'COBOL': 'Grace Hopper y equipo CODASYL',
    'Go': 'Robert Griesemer, Rob Pike, Ken Thompson (Google)',
    'Java': 'James Gosling (Sun Microsystems)',
    'C++': 'Bjarne Stroustrup',
    'Delphi': 'Anders Hejlsberg (Borland)',
    'Swift': 'Chris Lattner (Apple)',
    'Haskell': 'Lennart Augustsson, Simon Peyton Jones, et al.',
    'Kotlin': 'JetBrains (Andrey Breslav et al.)',
    'PowerShell': 'Jeffrey Snover (Microsoft)',
    'Ada': 'Jean Ichbiah (CII Honeywell Bull)',
    'Rust': 'Graydon Hoare (Mozilla)',
    'Perl': 'Larry Wall',
    'Visual Basic': 'Alan Cooper (Microsoft)',
    'Crystal': 'Ary Borenszweig, Juan Wajnerman, Brian Cardiff'
}

# %%
df['Created_By'] = df['Language'].map(creadores)
df.to_csv('PopularidadLenguajes.csv', index=False)
print("¡Columna 'Created_By' agregada y archivo guardado con éxito!")
# Out:
# ¡Columna 'Created_By' agregada y archivo guardado con éxito!

# %%
df[['Language', 'Year_Introduced', 'Created_By', 'Rank']].head()
# Out:
#    Language  Year_Introduced  \
# 0     Julia             2012
# 1   Fortran             1957
# 2       Zig             2016
# 3      Ruby             1995
# 4  Assembly             1949
#
#                                           Created_By  Rank
# 0  Jeff Bezanson, Stefan Karpinski, Viral B. Shah...   1.0
# 1                                  John Backus (IBM)   2.5
# 2                                      Andrew Kelley   2.5
# 3                                 Yukihiro Matsumoto   4.0
# 4                                     Kathleen Booth   5.0

# %%
df['Created_By'].unique()
# Out:
# <StringArray>
# ['Jeff Bezanson, Stefan Karpinski, Viral B. Shah, Alan Edelman',
#                                             'John Backus (IBM)',
#                                                 'Andrew Kelley',
#                                            'Yukihiro Matsumoto',
#                                                'Kathleen Booth',
#                                                    'José Valim',
#                                  'Anders Hejlsberg (Microsoft)',
#                                                'James Strachan',
#                                                  'Brendan Eich',
#                                                     'Brian Fox',
#                                                    'Gavin Wood',
#                                                 'Andreas Rumpf',
#                                                'Martin Odersky',
#                                 'Ross Ihaka y Robert Gentleman',
# ...

# %%
plt.figure(figsize=(10, 6))

# Cambiamos 'Rating_Pct' por 'Job_Demand_Index'
sns.histplot(df['Job_Demand_Index'], bins=10, kde=True, color='teal')

plt.title("Distribución del Índice de Demanda Laboral")
plt.xlabel("Índice de Demanda Laboral (0 - 100)")
plt.ylabel("Cantidad de Lenguajes")
plt.show()

# %%
df_modernos = df[(df['Year_Introduced'] >= 2000) & (df['Year_Introduced'] <= 2021)]

top_modernos = df_modernos.sort_values(by='Job_Demand_Index', ascending=False).head(10)

plt.figure(figsize=(10, 5))

sns.barplot(
    data=top_modernos,
    x='Language',
    y='Job_Demand_Index',
    palette='magma'
)

plt.title("Demanda Laboral de Lenguajes Modernos (Creados entre 2000 y 2021)")
plt.xlabel("Lenguaje")
plt.ylabel("Índice de Demanda Laboral (0 - 100)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_23296\703809173.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df = df.drop(columns=['Creator'])

# Guardamos el archivo corregido
df.to_csv('PopularidadLenguajes.csv', index=False)
print("Archivo corregido con éxito")
# Out:
# Archivo corregido con éxito

# %%
# Scatter Plot Rating vs Change
plt.figure(figsize=(10, 6))

# Usamos las columnas reales de tu dataset:
sns.scatterplot(
    data=df, 
    x="StackOverflow_Popularity", 
    y="Job_Demand_Index", 
    hue="Popularity_Rating",
    palette="viridis",
    s=100
)

plt.title("Relación entre Popularidad en Stack Overflow y Demanda Laboral")
plt.xlabel("Popularidad en Stack Overflow (0 - 100)")
plt.ylabel("Índice de Demanda Laboral (0 - 100)")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()
